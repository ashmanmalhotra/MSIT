# %%
56+96
# Out:
# 152

# %%
89-8
# Out:
# 81

# %%
89*23
# Out:
# 2047

# %%
89**56
# Out:
# 14650092678827525279640039374702037414437860790847659367069919288571044621724451628579390925833881943979088961

# %% [markdown]
# # Variables in Python

# %%
var1 = 10

# %%
var1
# Out:
# 10

# %%
type(var1)
# Out:
# int

# %%
var1 = 20.20
type(var1)
# Out:
# float

# %%
var1 = True
type(var1)
# Out:
# bool

# %%
var1 = [1, 2, 3, 4]
type(var1)
# Out:
# list

# %%
a = b = 10

# %%
a
# Out:
# 10

# %%
b
# Out:
# 10

# %%
a, b, c, d = 10, 20, 30, 40

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %%
c
# Out:
# 30

# %%
d
# Out:
# 40

# %%
a = 10
b = 20
c = a
a = b
b = c

# %%
a
# Out:
# 20

# %%
b
# Out:
# 10

# %%
a, b = 10, 20
temp = a
a = b
b = temp

# %%
a
# Out:
# 20

# %%
b
# Out:
# 10

# %%
a, b = 10, 20
a, b = b, a

# %%
a
# Out:
# 20

# %%
b
# Out:
# 10

# %%
print(a)
# Out:
# 20

# %%
print("The value of a is ", a)
# Out:
# The value of a is  20

# %%
a = 10

# %%
id(a)
# Out:
# 140719908057120

# %%
hex(id(a))
# Out:
# '0x7ffbe821f020'

# %%
a = 10
b = 10
c = 10
print("a", id(a))
print("b", id(b))
print("c", id(c))
# Out:
# a 140719908057120
# b 140719908057120
# c 140719908057120

# %%
id(10)
# Out:
# 140719908057120

# %%
a = 20

# %%
print("a", id(a))
print("b", id(b))
print("c", id(c))
# Out:
# a 140719908057440
# b 140719908057120
# c 140719908057120

# %%
var1 = input("Enter First Number : ")
# Out:
# Enter First Number : 90

# %%
var1
# Out:
# '90'

# %%
var1 + 20
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-37a86ff642b4> in <module>()
# ----> 1 var1 + 20
#
# TypeError: can only concatenate str (not "int") to str

# %%
aa = 10

# %%
id(aa)
# Out:
# 140719908057120

# %%
aa = 20

# %%
id(aa)
# Out:
# 140719908057440

# %%
num = 34343535000000000000000000000000000000000

# %%
num
# Out:
# 34343535000000000000000000000000000000000

# %%
type(num)
# Out:
# int

# %%
num = ...

# %%
num
# Out:
# ...

# %%
y = 20 + 201j

# %%
type(y)
# Out:
# complex

# %%
y.imag
# Out:
# 201.0

# %%
y.real
# Out:
# 20.0
